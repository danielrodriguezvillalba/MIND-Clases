# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0,4*np.pi,0.1)
y = np.sin(x)
z = np.cos(x)

# %%
plt.plot(x,y)
plt.plot(x,z)
plt.xlabel('X')
plt.ylabel("Sen(x) y Cos(x)")
# Out:
# Text(0,0.5,'Sen(x) y Cos(x)')
